# %%
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline

def polate(x,y,smoothing_factor=1,xcount=1000,xnewrange=[min(x),max(x)]):
    x=np.array(x)
    y=np.array(y)
    plt.plot(x,y,'ro')
    xnew=np.linspace(xnewrange[0],xnewrange[1],xcount)
    spl = UnivariateSpline(x, y)
    spl.set_smoothing_factor(smoothing_factor)
    plt.plot(xnew, spl(xnew), 'g')
    plt.show()
    
#Example    
x = np.linspace(-3, 3, 50)
y = np.exp(-x**2) + 0.1 * np.random.randn(50)
polate(x,y,2,1000,[-5,5])
polate(x,y,1,1000,[-5,5])
polate(x,y,0.5,1000,[-5,5]) #Manually have to set smoothing factor
